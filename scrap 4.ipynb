# %%
#Importing the required libraries
import requests
from bs4 import BeautifulSoup

# %%
#url of the website to scrap
url = 'http://www.skysports.com'

# %%
#using requests object to get the webpage
result = requests.get(url)

# %%
#Getting the contents of the webpage
webpage = result.content

#using beautifulsoup object to parse the webpage
sl_soup = BeautifulSoup(webpage, 'html.parser')

#closing the result objecxt
result.close
# Out:
# <bound method Response.close of <Response [200]>>

# %%
#printing the formatted version of the webpage
print(sl_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Sky Sports - Sports News, Transfers, Scores | Watch Live Sport
#   </title>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <meta content="Sky Sports - Sports News, Transfers, Scores | Watch Live Sport" name="title"/>
#   <meta content="Watch the best live coverage of your favourite sports: Football, Golf, Rugby, Cricket, F1, Boxing, NFL, NBA, plus the latest sports news, transfers &amp; scores." name="description"/>
# ...

# %%
#print all the links
for href in sl_soup.find_all('a', href=True):
    print(href['href'])
# Out:
# #main
# #site-footer
# /
# #no-js-nav
# /
# #no-js-nav
# /football
# /f1
# /cricket
# /rugby-union
# /rugby-league
# /golf
# /boxing
# /nfl
# /tennis
# /racing
# /darts
# /nba
# /netball
# /gaa
# /mma
# /more-sports
# /live-scores
# /watch/video
# /watch
# https://m.skybet.com?aff=9749&dcmp=ss_main_nav
# /games
# #no-js-nav
# /transfer-centre
# /watch/sport-on-sky
# /get-sky?dcmp=gss_more_dropdown
# /watch/tv-shows
# /watch/tv-guide
# https://www.sky.com/shop/tv/sky-go/?dcmp=skygo_ss.com_more
# http://www.nowtv.com/promo/sky-sports?dcmp=ilc_SSNTV_skysports_hardcode_moredropdownlink
# https://www.kickitout.org/forms/online-reporting-form
# /football/news/topic/8724/black-lives-matter
# /sky-zero
# /podcasts
# /mobile
# https://twitter.com/SkySports
# https://www.facebook.com/SkySports
# /contact-us
# /workatskysports
# https://www.sky.com/help/articles/skycom-terms-and-conditions
# /watch
# /football
# ...
